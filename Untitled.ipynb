# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url= 'https://punchng.com/topics/news/'
response = requests.get(url).text

# %%
articles = []

categories=['news','metro-plus','sports','politics','business','editorial','columns','podcast']

for category in categories:
    url= f'https://punchng.com/topics/{category}/'
    response = requests.get(url).text

    soup = BeautifulSoup(response, 'html.parser')

    article_container = soup.find('div' , class_ ='latest-news-timeline-section')

    article_temp = article_container.find_all_next('article')



    for article in article_temp:
        title = article.find('h1', 'post-title').text.strip()
        excerpt = article.find('p', 'post-excerpt').text.strip()
        date = article.find('span', 'post-date')
        link = article.find('a')['href']



        articles.append({
            'category' : category,
            'title' : title,
            'excerpt' : excerpt,
            'date' : date,
            'link' : link
        })


    for article in articles:
        article_page= requests.get(article['link']).text.strip()

        article_soup = BeautifulSoup(article_page, 'html.parser')

        article['author'] = article_soup.find('span',class_= 'post-author').text.strip().replace('By' ,'')

        article['content'] = article_soup.find('div', class_='post-content').text.strip()
        
        
        if article_soup.find('div', class_= 'post-image-wrapper') is None:
            article['image'] = ''
        else:
            article['image'] = article_soup.find('div', class_= 'post-image-wrapper').find_next('figure').find_next('img')['src']

    
    print(f'category {category} is completed')

    
    
    
    
df= pd.DataFrame(articles)
df
# Out:
# category news is completed
# category metro-plus is completed
# category sports is completed
# category politics is completed
# category business is completed
# category editorial is completed
# category columns is completed
# category podcast is completed
#     category                                              title  \
# 0       news  Tinubu appoints new RECs for Lagos, Rivers,  s...
# 1       news  Police recruitment: Kaduna, Adamawa lead as An...
# 2       news     Reps vow to tackle flight delays, cancellation
# 3       news  FCT police arrest suspected robbers, carjacker...
# 4       news       UN lauds Niger's investment in green economy
# ..       ...                                                ...
# 243  podcast  PUNCH Panorama: A prayer for Lagos, Nigeria at...
# 244  podcast                  PUNCH Panorama: Use your ‘devils’
# 245  podcast   PUNCH Panorama: Why do some married men eat out?
# 246  podcast  PUNCH Panorama: When marriage gets tiring, wha...
# 247  podcast                     Daily Podcast: Merry Christmas
#
#                                                excerpt  \
# 0    President Bola Tinubu on Wednesday appointed n...
# 1    Kaduna State is currently leading in the numbe...
# 2    Lawmakers in the Federal House of Representati...
# 3    Operatives of the Federal Capital Territory Po...
# 4    The United Nations has commended the Niger Sta...
# ..                                                 ...
# 243  From months to weeks to days and now, we are c...
# 244  As we near the end of 2022, there is a need fo...
# 245  Away from serious national issues, let’s discu...
